# %% [markdown]
# ## **API**

# %% [markdown]
# # API are nothing but just data pipeline

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=1e4f28753c1ecfb5591c9f690db68a20&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 27.7246,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.712,
#    'vote_count': 28513},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
temp_df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2   803796                             KPop Demon Hunters
# 3      240                          The Godfather Part II
# 4      424                               Schindler's List
# 5      389                                   12 Angry Men
# 6      129                                  Spirited Away
# 7      155                                The Dark Knight
# 8    19404                    Dilwale Dulhania Le Jayenge
# 9      497                                 The Green Mile
# 10  496243                                       Parasite
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13  372058                                     Your Name.
# 14      13                                   Forrest Gump
# ...

# %%
temp_df.head()
# Out:
#        id                     title  \
# 0     278  The Shawshank Redemption
# 1     238             The Godfather
# 2  803796        KPop Demon Hunters
# 3     240     The Godfather Part II
# 4     424          Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     27.7246
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     27.4118
# 2  When K-pop superstars Rumi, Mira and Zoey aren...   2025-06-20    243.7102
# 3  In the continuing saga of the Corleone crime f...   1974-12-20     15.2504
# 4  The true story of how businessman Oskar Schind...   1993-12-15     12.2727
#
#    vote_average  vote_count
# 0         8.712       28513
# 1         8.688       21590
# 2         8.629         460
# 3         8.571       13043
# 4         8.565       16520

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import pandas as pd

df = pd.DataFrame()

for i in range(1, 429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=1e4f28753c1ecfb5591c9f690db68a20&language=en-US&page={}'.format(i))
    
    if response.status_code == 200:
        temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
        df = pd.concat([df, temp_df], ignore_index=True)
    else:
        print(f"Failed to fetch page {i}: status code {response.status_code}")

# final DataFrame
print(df)
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2     803796        KPop Demon Hunters
# 3        240     The Godfather Part II
# 4        424          Schindler's List
# ...      ...                       ...
# 8555  862551                   Me Time
# 8556    9030                   The Eye
# 8557  395458                Suburbicon
# 8558  290555                    Wolves
# 8559   23514             The Rum Diary
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     When K-pop superstars Rumi, Mira and Zoey aren...   2025-06-20
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...                                                 ...          ...
# ...

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2     803796        KPop Demon Hunters
# 3        240     The Godfather Part II
# 4        424          Schindler's List
# ...      ...                       ...
# 8555  862551                   Me Time
# 8556    9030                   The Eye
# 8557  395458                Suburbicon
# 8558  290555                    Wolves
# 8559   23514             The Rum Diary
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     When K-pop superstars Rumi, Mira and Zoey aren...   2025-06-20
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...                                                 ...          ...
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
